# %%
# %matplotlib notebook
import numpy as np
import os
import scipy
import scipy.stats
import matplotlib as mpl
# mpl.use('pdf')
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D


GOLDEN_RATIO = 1.618

#onecolumn_width = 3.487
onecolumn_width = 3.335 # usenixstylefile lists textwidth as 7in, with colsep 0.33 (7-0.33)/2 = 3.335
#onecolumn_width2 = 3.335 # usenixstylefile lists textwidth as 7in, with colsep 0.33 (7-0.33)/2 = 3.335
onecolumn_height = onecolumn_width / GOLDEN_RATIO
#onecolumn_height2 = onecolumn_width2 / GOLDEN_RATIO # usenixstylefile lists textwidth as 7in, with colsep 0.33 (7-0.33)/2 = 3.335

twocolumn_width = onecolumn_width * 2
twocolumn_height = twocolumn_width / GOLDEN_RATIO
twocolumn_height_half = twocolumn_height / 2
# 
# plt.rc('font', family='serif', serif='Times')
# plt.rc('text', usetex=True)
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{mathptmx}',
#                                        r'\usepackage[T1]{fontenc}',
#                                        r'\usepackage[utf8]{inputenc}',
#                                        r'\usepackage{pslatex}']
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=6)
plt.rc('axes', labelsize=8)

out_dir = 'byproducts/'



def sample_plotting():
    """
    :return:
    """
    data = np.random.rand(10, 10)
    fig = plt.figure()
    ax = fig.add_subplot(121, projection='3d')

    _x = np.arange(len(data[0]))
    _y = np.arange(len(data))
    _xx, _yy = np.meshgrid(_x, _y)
    x, y = _xx.ravel(), _yy.ravel()

    topp = data.ravel()
    bottom = np.zeros_like(topp)
    width = depth = 0.50

    ax.bar3d(x, y, bottom, width, depth, topp, shade=True)
    ax.set_title("Super cool title")

    fig.set_size_inches(onecolumn_width, onecolumn_height)
    plt.show()
#     fig.savefig(os.path.join(out_dir, '{}.pdf'.format(str(sample_plotting.__name__))))
    # fig.subplots_adjust()

# %%
sample_plotting()
# Out:
# <img src="data:image/png;base64,..." width="549">

# %%
def plot(x):
    """
    :return:
    """
    data = x
    fig = plt.figure()
    ax = fig.add_subplot(121, projection='3d')

    _x = np.arange(len(data[0]))
    _y = np.arange(len(data))
    _xx, _yy = np.meshgrid(_x, _y)
    x, y = _xx.ravel(), _yy.ravel()

    topp = data.ravel()
    bottom = np.zeros_like(topp)
    width = depth = 0.50
    
    
    ax.bar3d(*data, bottom, width, depth, topp, shade=True)
    ax.set_title("Plot of Delta")

    fig.set_size_inches(onecolumn_width, onecolumn_height)
    plt.show()

# %%
#Using this one

def comparison_plot(batched_t, original, name):
    
    n_col = 4
    n_rows = 2
    fig, axes = plt.subplots(nrows=n_rows, ncols=n_col, sharey=True, sharex=True)

    original = np.array(original)
    
    for i in range(n_rows):
        k = 0
        for j in range(n_col):
            
            #Plot original first
            if i is 0:
                showing = original[k]

                if batched_t.shape[-1] == 3:
                    showing = showing
                else:
                    showing = showing.permute(1, 2, 0)
                    
            #Plot adversarial below it        
            else:
                showing = batched_t[k]

                if batched_t.shape[-1] == 3:
                    showing = showing
                else:
                    showing = showing.permute(1, 2, 0)
                    
                    
            axes[i, j].imshow(showing)
            k += 1

    fig.set_size_inches(twocolumn_width, twocolumn_height)
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, '{}.pdf'.format(name)))

# %%
import pickle as pkl
import skvideo.io

pkl_path = 'D:\\College\\Research\\December 2018 Video Captioning Attack\\3212019 results\\032119-171855\\'
video_path = 'D:\\College\\Research\\December 2018 Video Captioning Attack\\video captioner\\YouTubeClips\\'

path_list =  [os.path.join(root, name)
                for root, dirs, files in os.walk(pkl_path)
                for name in files
                if name.endswith((".pkl"))]

for path in path_list:

    split_path = path.split('\\')
    split_filename = split_path[-1].split('.')[0]
    name = split_filename.replace('_adversarial', '')
    
    
    with open(path, 'rb') as f:
        print("Loaded %s" % path)
        x = pkl.load(f)
        
    originalvid_path = video_path + name + ".avi"
    original = skvideo.io.vread(originalvid_path)[0:4]
#pass_in, iterations, delta, original_caption, target_caption
    img = x['pass_in']
    delta = x['delta']
    print(img.shape)
    print("{}\nOriginal caption: {}\nTarget caption: {}".format(x['iterations'], x['original_caption'], x['target_caption']))
    comparison_plot(img/255., original, name)

# plot_frames(x['pass_in']/255.)
# plot_frames(delta*255)
# Out:
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\AJJ-iQkbRNE_97_109_adversarial.pkl
# (4, 316, 560, 3)
# 1000
# Original caption: <sos> A man slicing pineapple <eos>
# Target caption: <sos> A papaya is being peeled <eos>
# <img src="data:image/png;base64,..." width="667">
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\za-9mBZyNfQ_330_336_adversarial.pkl
# (4, 360, 480, 3)
# 1000
# Original caption: <sos> Two men are dancing <eos>
# Target caption: <sos> People are racing motorcycles <eos>
# <img src="data:image/png;base64,..." width="667">
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\zFIn8DeV5PM_20_33_adversarial.pkl
# (4, 480, 854, 3)
# 1000
# Original caption: <sos> A person is playing a keyboard piano <eos>
# Target caption: <sos> anyone is making dish <eos>
# <img src="data:image/png;base64,..." width="667">
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\zkTn5Ef1Oig_70_75_adversarial.pkl
# (4, 360, 480, 3)
# 66
# Original caption: <sos> The elephant and her baby splashed water on themselves <eos>
# Target caption: <sos> A boy <UNK> the floor <eos>
# <img src="data:image/png;base64,..." width="667">
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\zpgW7m7_LZw_2_15_adversarial.pkl
# (4, 360, 480, 3)
# 12
# Original caption: <sos> A little boy is playing golf <eos>
# Target caption: <sos> A person is frying food <eos>
# <img src="data:image/png;base64,..." width="667">
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\zTn-nNj5Bng_61_77_adversarial.pkl
# (4, 480, 600, 3)
# 292
# Original caption: <sos> A woman is riding a horse <eos>
# Target caption: <sos> Several women dance <eos>
# <img src="data:image/png;base64,..." width="667">
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\zuYZ5kPatJE_78_116_adversarial.pkl
# (4, 360, 480, 3)
# 440
# Original caption: <sos> a cat is turning its head <eos>
# Target caption: <sos> the old lady slicing carrot <eos>
# <img src="data:image/png;base64,..." width="667">
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\032119-171855\zv2RIbUsnSw_335_341_adversarial.pkl
# (4, 720, 1280, 3)
# 36
# Original caption: <sos> The woman is being wheeled into the hospital <eos>
# Target caption: <sos> <UNK> are dancing <eos>
# <img src="data:image/png;base64,..." width="667">

# %%
#Script to get L2 norm of deltas, average iterations, average cosine similiarity for a c value

import pickle as pkl
import re
import skvideo.io
from scipy import spatial
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer



c_vals = [0.01, 0.1, 1, 10, 100] 
for c in c_vals:
    pkl_path = 'D:\\College\\Research\\December 2018 Video Captioning Attack\\3212019 results\All c results\\{}\\'.format(c)
    video_path = 'D:\\College\\Research\\December 2018 Video Captioning Attack\\video captioner\\YouTubeClips\\'

    print(pkl_path)
    path_list =  [os.path.join(root, name)
                    for root, dirs, files in os.walk(pkl_path)
                    for name in files
                    if name.endswith((".pkl"))]
    
    #pass_in, iterations, delta, final_caption, original_caption, target_caption
    for path in path_list:
        avg_delta = []
        total_iterations = []
        cos_similarity = []
        

        with open(path, 'rb') as f:
            print("Loaded %s" % path)
            x = pkl.load(f)

        pass_in = x['pass_in']
        delta = x['delta']
        iterations = x['iterations']
        target_caption = x['target_caption'].replace('<sos>', '').replace('<eos>', '')
        final_caption = x['final_caption'].replace('<sos>', '').replace('<eos>', '')
        
        documents = (target_caption, final_caption)
        tfidf_vectorizer=TfidfVectorizer(analyzer="char")
        tfidf_matrix=tfidf_vectorizer.fit_transform(documents).toarray()

        cosine_similarity = 1 - spatial.distance.cosine(tfidf_matrix[0], tfidf_matrix[1])
        cos_similarity.append(cosine_similarity)
        for f_delta in delta:
            avg_delta.append(f_delta[f_delta != 0])
        total_iterations.append(iterations)

    print("C value: {}\nL2 Norm of Delta:{}\n".format(c, np.linalg.norm(avg_delta, 2)))
    print("Average Cosine Similarity: {}\nAverage number of iterations: {}\n".format(np.mean(cos_similarity), np.mean(total_iterations)))
# print(np.mean(avg_delta))
# Out:
# D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.01\
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.01\AJJ-iQkbRNE_97_109_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.01\za-9mBZyNfQ_330_336_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.01\zkTn5Ef1Oig_70_75_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.01\zpgW7m7_LZw_2_15_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.01\zuYZ5kPatJE_78_116_adversarial.pkl
# C value: 0.01
# L2 Norm of Delta:5.63601016998291
#
# Average Cosine Similarity: 0.9813755894810428
# Average number of iterations: 520.0
#
# D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.1\
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.1\AJJ-iQkbRNE_97_109_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.1\za-9mBZyNfQ_330_336_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.1\zkTn5Ef1Oig_70_75_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.1\zpgW7m7_LZw_2_15_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\0.1\zuYZ5kPatJE_78_116_adversarial.pkl
# C value: 0.1
# L2 Norm of Delta:8.96769905090332
#
# Average Cosine Similarity: 0.9813755894810428
# Average number of iterations: 379.0
#
# D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\1\
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\1\AJJ-iQkbRNE_97_109_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\1\za-9mBZyNfQ_330_336_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\1\zkTn5Ef1Oig_70_75_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\1\zpgW7m7_LZw_2_15_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\1\zuYZ5kPatJE_78_116_adversarial.pkl
# C value: 1
# L2 Norm of Delta:10.067652702331543
#
# Average Cosine Similarity: 0.9813755894810428
# Average number of iterations: 346.0
#
# D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\10\
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\10\AJJ-iQkbRNE_97_109_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\10\za-9mBZyNfQ_330_336_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\10\zkTn5Ef1Oig_70_75_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\10\zpgW7m7_LZw_2_15_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\10\zuYZ5kPatJE_78_116_adversarial.pkl
# C value: 10
# L2 Norm of Delta:3.234873056411743
#
# Average Cosine Similarity: 0.9684959969581861
# Average number of iterations: 11.0
#
# D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\100\
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\100\AJJ-iQkbRNE_97_109_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\100\za-9mBZyNfQ_330_336_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\100\zkTn5Ef1Oig_70_75_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\100\zpgW7m7_LZw_2_15_adversarial.pkl
# Loaded D:\College\Research\December 2018 Video Captioning Attack\3212019 results\All c results\100\zuYZ5kPatJE_78_116_adversarial.pkl
# C value: 100
# L2 Norm of Delta:5.480123043060303
#
# Average Cosine Similarity: 0.9803789354850789
# Average number of iterations: 132.0
